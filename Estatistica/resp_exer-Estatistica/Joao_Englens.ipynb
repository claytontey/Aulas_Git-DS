# %% [markdown]
# # 📊 Estudo de Caso: Desempenho de Alunos
#
# Você foi contratado como cientista de dados para analisar o desempenho de uma turma.
# Seu objetivo é gerar insights para melhorar o ensino.
#
# Utilizando o material e as métricas apresentadas na aula de hoje, apresente seus _insigths_ para o _dataset_ apresentado:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('dataset_estudo_estatistica.csv')
df.head()
# Out:
#    horas_estudo  acessos_plataforma  faltas  tempo_resolucao  bolsa_estagio  \
# 0             7                  39      10              167              1
# 1             4                  39       9              183              1
# 2             8                  37       6              166              0
# 3             5                   9      11              109              0
# 4             7                 110       8              166              1
#
#    turno linguagem       nota
# 0  Manhã      Java  75.596400
# 1  Manhã      Java   0.000000
# 2  Manhã         C  66.178579
# 3  Noite    Python  35.059806
# 4  Noite         C  57.371902

# %% [markdown]
# ## Exercício 1
# Descreva e analise algo relevante nos dados.

# %%
#Media das faltas dos alunos
print("Media de faltas:",df['faltas'].mean())
print("Mediana das faltas:",df['faltas'].median())
# Out:
# Media de faltas: 5.275
# Mediana das faltas: 5.0

# %% [markdown]
# ## Exercício 2
# Descreva e analise algo relevante nos dados.

# %%
#Quantos alunos atualmente tem bolsa de estagio
print("Total de alunos com bolsa de estagio:",df['bolsa_estagio'].sum())
# Out:
# Total de alunos com bolsa de estagio 41

# %% [markdown]
# ## Exercício 3
# Descreva e analise algo relevante nos dados.

# %%
# Qual o tempo medio de resolução entre os alunos
print("Tempo medio das resolucoes:",df['tempo_resolucao'].mean()) 
print("Mediana das resolucoes:",df['tempo_resolucao'].median())
# Out:
# Tempo medio das resolucoes: 128.4125
# Mediana das resolucoes: 138.5

# %% [markdown]
# ## Exercício 4
# Descreva e analise algo relevante nos dados.

# %%
#Quantidade de alunos de dia e de noite
print("Total de alunos de dia:",(df['turno'] == 'Manhã').sum())
print("Total de alunos de noite:",(df['turno'] == 'Noite').sum())
# Out:
# Total de alunos de dia: 35
# Total de alunos de noite: 45

# %% [markdown]
# ## Exercício 5
# Descreva e analise algo relevante nos dados.

# %%
# Qual a linguagem mais usada entre os alunos
java=(df['linguagem'] == 'Java').sum()
c=(df['linguagem'] == 'C').sum()
python=(df['linguagem'] == 'Python').sum()
print(java,c,python)
print("A linguagem mais usada foi java com ",java)
# Out:
# 31 20 29
# A linguagem mais usada foi java com   31

# %% [markdown]
# ## Exercício 6
# Descreva e analise algo relevante nos dados.

# %%
#Ver se existe correlação entre o tempo de estudo e as notas
corr=df['horas_estudo'].corr(df['nota'])
print(corr)
print("Com esse resultado podemos ver que quantos mais estuda maior tende ser a nota")
# Out:
# 0.9180856640311844
# Com esse resultado podemos ver que quantos mais estuda maior tende ser a nota

# %% [markdown]
# ## Exercício 7
# Descreva e analise algo relevante nos dados.

# %%
#Verificar se os acessos a plataforma está trazendo melhores resultados
corr=df['acessos_plataforma'].corr(df['nota'])
print(corr)
print("Com esse resultado verificamos que a plataforma talvez não esteja trazendo tantos resultados aos alunos")
# Out:
# -0.14007793949003985
# Com esse resultado verificamos que a plataforma talvez não esteja trazendo tantos resultados aos alunos

# %% [markdown]
# ## Exercício 8
# Descreva e analise algo relevante nos dados.

# %%
#Verificar se notas melhores acarretam em mais bolsas de estagio
corr=df['nota'].corr(df['bolsa_estagio'])
print(corr)
print("Não podemos afirmar se maiores notas levam a mais bolsas de estagios")
# Out:
# -0.0006795154264091148
# Não podemos afirmar se maiores notas levam a mais bolsas de estagios

# %% [markdown]
# ## Exercício 9
# Descreva e analise algo relevante nos dados.

# %%
#verificar se as faltas pioram a nota
corr=df['nota'].corr(df['faltas'])
print(corr)
print("Podemos ver uma tendencia de quando as faltas comecam a aumentar as notas tendem a diminuir um pouco")
# Out:
# -0.19672431514472122
# Não podemos afirmar se maiores notas levam a mais bolsas de estagios

# %% [markdown]
# ## Exercício 10
# Descreva e analise algo relevante nos dados.

# %%
# Verificar se os alunos gastam suas horas de estudo dentro da plataforma
corr=df['horas_estudo'].corr(df['acessos_plataforma'])
print(corr)
print("Não podemos afirmar que os alunos gastam seu tempo de estudo dentro da plataforma")
# Out:
# -0.0956679419855056

# %% [markdown]
# ## Exercício 11
# Descreva e analise algo relevante nos dados.

# %%
#Verificar se o estagio aumenta a quantidade de falta dos alunos
corr=df['bolsa_estagio'].corr(df['faltas'])
print(corr)
print("Podemos ver um leve crescimento das faltas quando se tem bolsas de estagio")
# Out:
# 0.24452177463114863
# Podemos ver um leve crescimento das faltas quando se tem bolsas de estagio

# %% [markdown]
# ## Exercício 12
# Descreva e analise algo relevante nos dados.

# %%
#A media das notas em relação a linguagem
media_notas = df.groupby('linguagem')['nota'].mean()
print(media_notas)
# Out:
# linguagem
# C         47.281207
# Java      40.353170
# Python    47.387763
# Name: nota, dtype: float64

# %% [markdown]
# ## Exercício 13
# Descreva e analise algo relevante nos dados.

# %%
#Qual linguagem tem mais bolsas de estagio
media_notas = df.groupby('linguagem')['bolsa_estagio'].mean()
print(media_notas)
# Out:
# linguagem
# C         0.650000
# Java      0.580645
# Python    0.344828
# Name: bolsa_estagio, dtype: float64

# %% [markdown]
# ## Exercício 14
# Descreva e analise algo relevante nos dados.

# %%
#Qual turno tem maior media de notas
media_notas = df.groupby('turno')['nota'].mean()
print(media_notas)
# Out:
# turno
# Manhã    47.302129
# Noite    42.560956
# Name: nota, dtype: float64

# %% [markdown]
# ## Exercício 15
# Descreva e analise algo relevante nos dados.

# %%
#A media e a mediana do tempo de estudo
print("Media de tempo de estudo:",df['horas_estudo'].mean())
print("Mediana de tempo de estudo:",df['horas_estudo'].median())
# Out:
# Media de tempo de estudo: 5.3625
# Mediana de tempo de estudo: 5.0

# %% [markdown]
# ## Exercício 16
# Descreva e analise algo relevante nos dados.

# %%
#A media das notas e a mediana das notas
print("Media das notas:",df['nota'].mean())
print("Mediana das notas:",df['nota'].median())
# Out:
# Media das notas: 44.63521894022
# Mediana das notas: 47.50616117512556

# %% [markdown]
# ## Exercício 17
# Descreva e analise algo relevante nos dados.

# %%
#Verificar a variação da notas
print(df['nota'].std())
print("Com essa informação vemos que as notas tem uma grande variação entre elas")
# Out:
# 27.985507442917005
# Com essa informação vemos que as notas tem uma grande variação entre elas

# %% [markdown]
# ## Exercício 18
# Descreva e analise algo relevante nos dados.

# %%
#Verificar a variação do acesso a plataforma
print(df['acessos_plataforma'].std())
print("Com essa informação vemos que alguns alunos acessam bastante a plataforma e outros não")
# Out:
# 33.92019673933869
# Com essa informação vemos que as notas tem uma grande variação entre elas

# %% [markdown]
# ## Exercício 19
# Descreva e analise algo relevante nos dados.

# %%
#Verificar se o tempo de resolução afeta na nota
corr=df['nota'].corr(df['tempo_resolucao'])
print(corr)
print("Com esse resultado verificamos que o tempo de resolução não afeta diretamente na nota")
# Out:
# -0.030751054744315196
# Com esse resultado verificamos que o tempo de resolução não afeta diretamente na nota

# %% [markdown]
# ## Exercício 20
# Descreva e analise algo relevante nos dados.

# %%
#Verificar qual tuno tem mais bolsas de estagio
turno_estagio = df.groupby('turno')['bolsa_estagio'].sum()
print(turno_estagio)
print("Verificamos que mais alunos do noturno tem mais estagios")
# Out:
# turno
# Manhã    15
# Noite    26
# Name: bolsa_estagio, dtype: int64
# Verificamos que mais alunos do noturno tem mais estagios
