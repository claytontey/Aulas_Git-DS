# %% [markdown]
# # 📊 Estudo de Caso: Desempenho de Alunos
#
# Você foi contratado como cientista de dados para analisar o desempenho de uma turma.
# Seu objetivo é gerar insights para melhorar o ensino.
#
# Utilizando o material e as métricas apresentadas na aula de hoje, apresente seus _insigths_ para o _dataset_ apresentado:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('dataset_estudo_estatistica.csv')
df.head()
# Out:
#    horas_estudo  acessos_plataforma  faltas  tempo_resolucao  bolsa_estagio  \
# 0             7                  39      10              167              1
# 1             4                  39       9              183              1
# 2             8                  37       6              166              0
# 3             5                   9      11              109              0
# 4             7                 110       8              166              1
#
#    turno linguagem       nota
# 0  Manhã      Java  75.596400
# 1  Manhã      Java   0.000000
# 2  Manhã         C  66.178579
# 3  Noite    Python  35.059806
# 4  Noite         C  57.371902

# %% [markdown]
# ## Exercício 1
# Descreva e analise algo relevante nos dados.

# %%
#linguagem mais utilizada
maisuso=df["linguagem"].mode()
print(maisuso)
# Out:
# 0    Java
# Name: linguagem, dtype: str

# %% [markdown]
# ## Exercício 2
# Descreva e analise algo relevante nos dados.

# %%
#media de tempo de estudo
mediaestudo=df["horas_estudo"].mean()
print(mediaestudo)
# Out:
# 5.3625

# %% [markdown]
# ## Exercício 3
# Descreva e analise algo relevante nos dados.

# %%
#media numero de acessos
mediaacessos=df["acessos_plataforma"].mean()
print(mediaacessos)
# Out:
# 59.95

# %% [markdown]
# ## Exercício 4
# Descreva e analise algo relevante nos dados.

# %%
#media numero de faltas
mediafaltas=df["faltas"].mean()
print(mediafaltas)
# Out:
# 5.275

# %% [markdown]
# ## Exercício 5
# Descreva e analise algo relevante nos dados.

# %%
#media de tempo de resolucao
mediares=df["tempo_resolucao"].mean()
print(mediares)
# Out:
# 128.4125

# %% [markdown]
# ## Exercício 6
# Descreva e analise algo relevante nos dados.

# %%
#media de notas
medianota=df["nota"].mean()
print(medianota)
# Out:
# 44.63521894022

# %% [markdown]
# ## Exercício 7
# Descreva e analise algo relevante nos dados.

# %%
#media de nota por tempo de estudo
df.groupby("horas_estudo")["nota"].mean()
# Out:
# horas_estudo
# 1     5.592597
# 2     8.121192
# 3    27.341675
# 4    30.830388
# 5    39.720959
# 6    49.641010
# 7    59.555967
# 8    65.112856
# 9    88.426642
# Name: nota, dtype: float64

# %% [markdown]
# ## Exercício 8
# Descreva e analise algo relevante nos dados.

# %%
#media de nota por linguagem
df.groupby("linguagem")["nota"].mean()
# Out:
# linguagem
# C         47.281207
# Java      40.353170
# Python    47.387763
# Name: nota, dtype: float64

# %% [markdown]
# ## Exercício 9
# Descreva e analise algo relevante nos dados.

# %%
#media de horas de estudo por linguagem
df.groupby("linguagem")["faltas"].mean()
# Out:
# linguagem
# C         3.750000
# Java      6.225806
# Python    5.310345
# Name: faltas, dtype: float64

# %% [markdown]
# ## Exercício 10
# Descreva e analise algo relevante nos dados.

# %%
#nota media por tempo de resolucao
df.groupby("tempo_resolucao")["nota"].mean()
# Out:
# tempo_resolucao
# 21     89.185322
# 26     57.407929
# 28     80.276799
# 30     17.555546
# 40     73.730891
# 41      0.000000
# 52      6.936311
# 56     70.252046
# 58     65.685085
# 61     49.324443
# 67     62.210114
# 71     74.083989
# 73     49.922237
# 79     47.573688
# 87     19.110435
# 94     35.540146
# 101    28.867399
# 103    43.701437
# 109    17.529903
# 112    42.955177
# 115    67.502533
# 118    37.244404
# 123    59.780827
# 129     4.924247
# 131    20.400240
# 132    17.620432
# 134    64.232158
# 135    87.489438
# 138    28.392867
# 139     0.000000
# 147    31.725255
# 148    35.829671
# 150    93.141884
# 154    47.969648
# 155    87.771806
# 159    45.665746
# 161    47.438634
# 163    87.331979
# 164    79.777842
# 165    45.235305
# 166    43.329588
# 167    47.149318
# 170    33.277828
# 171    79.749976
# 172    52.143370
# 177    80.820541
# 178    12.967523
# 179    40.183436
# 180    41.149314
# 182    58.347540
# 183     3.616474
# 185    10.909655
# 187    30.195225
# 188    80.784599
# 195    54.073229
# 197    56.052060
# Name: nota, dtype: float64

# %% [markdown]
# ## Exercício 11
# Descreva e analise algo relevante nos dados.

# %%
#media de faltas de alunos com bolsa e sem (0 sem e 1 com bolsa)
df.groupby("bolsa_estagio")["faltas"].mean()
# Out:
# bolsa_estagio
# 0    4.358974
# 1    6.146341
# Name: faltas, dtype: float64

# %% [markdown]
# ## Exercício 12
# Descreva e analise algo relevante nos dados.

# %%
#media de alunos com bolsa e sem bolsa
df.groupby("bolsa_estagio")["nota"].mean()
# Out:
# bolsa_estagio
# 0    44.654595
# 1    44.616788
# Name: nota, dtype: float64

# %% [markdown]
# ## Exercício 13
# Descreva e analise algo relevante nos dados.

# %%
#variancia de alunos com bolsa em relação as horas de estudo
df.groupby("bolsa_estagio")["horas_estudo"].var()
# Out:
# bolsa_estagio
# 0    6.693657
# 1    7.106098
# Name: horas_estudo, dtype: float64

# %% [markdown]
# ## Exercício 14
# Descreva e analise algo relevante nos dados.

# %%
#alunos com nota acima de 50(aprovados)
(df["nota"] > 50).sum()
# Out:
# np.int64(36)

# %% [markdown]
# ## Exercício 15
# Descreva e analise algo relevante nos dados.

# %%
#mediana das notas com bolsa e sem bolsa
df.groupby("bolsa_estagio")["nota"].median()
# Out:
# bolsa_estagio
# 0    45.665746
# 1    47.573688
# Name: nota, dtype: float64

# %% [markdown]
# ## Exercício 16
# Descreva e analise algo relevante nos dados.

# %%
#mediana das horas de estudo com e sem bolsa
df.groupby("bolsa_estagio")["horas_estudo"].median()
# Out:
# bolsa_estagio
# 0    5.0
# 1    5.0
# Name: horas_estudo, dtype: float64

# %% [markdown]
# ## Exercício 17
# Descreva e analise algo relevante nos dados.

# %%
# desvio padrao por bolsa
df.groupby("bolsa_estagio")["nota"].std()
# Out:
# bolsa_estagio
# 0    25.605107
# 1    30.396651
# Name: nota, dtype: float64

# %% [markdown]
# ## Exercício 18
# Descreva e analise algo relevante nos dados.

# %%
#desvio padrao de horas de estudo por bolsa
df.groupby("bolsa_estagio")["horas_estudo"].std()
# Out:
# bolsa_estagio
# 0    2.587210
# 1    2.665726
# Name: horas_estudo, dtype: float64

# %% [markdown]
# ## Exercício 19
# Descreva e analise algo relevante nos dados.

# %%
# mediana dos aprovados(nota>50)
df[df["nota"] > 50]["nota"].median()
# Out:
# np.float64(66.84055592764284)

# %% [markdown]
# ## Exercício 20
# Descreva e analise algo relevante nos dados.

# %%
#variancia numero de faltas
varfaltas=df["faltas"].var()
print(varfaltas)
# Out:
# 13.518354430379748
