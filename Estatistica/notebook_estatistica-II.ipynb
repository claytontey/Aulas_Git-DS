# %% [markdown]
# # 📊 Estudo de Caso - Estatística em Ciência de Dados

# %%
import pandas as pd

df = pd.read_csv('dataset_estatistica.csv')
df.head()

# %% [markdown]
# ## 1. Média, Mediana, Moda

# %%
# completar

# %% [markdown]
# ## 2. Variância e Desvio Padrão

# %%
# completar

# %% [markdown]
# ## 3. Histograma

# %%
# completar

# %% [markdown]
# ## 4. Correlação

# %%
# completar

# %% [markdown]
# ## 5. Outliers

# %%
# completar

# %% [markdown]
# ## 6. Z-score

# %%
# completar
